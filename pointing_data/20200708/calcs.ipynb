# %%
import matplotlib
from matplotlib import style
style.use('ggplot')
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u

# %%
el = np.linspace(15, 90, 100) * u.deg

# %%
zc_trans = 9.453
zc_sky = 0.3
tf = -37.32
tx = -5.16

# %%
tiltx_cos_coeff = -1*tf / zc_sky
tiltx_tan_coeff = -1*tx / zc_sky
y_cos_coeff = zc_trans * tiltx_cos_coeff
y_tan_coeff = zc_trans * tiltx_tan_coeff
tiltx_cos_coeff, y_cos_coeff
# Out:
# (124.4, 1175.9532)

# %%
current_model = 119.6*np.cos(el) - 66.1*np.sin(el)
tpoint_model = tiltx_cos_coeff*np.cos(el) + tiltx_tan_coeff * np.cos(el)/np.sin(el) - 69.32
plt.plot(el, current_model, label="elcoll")
plt.plot(el, tpoint_model, label="tpoint")
plt.ylabel("Tilt X (arcsec)")
plt.xlabel("Elevation (deg)")
plt.legend()
plt.show()

# %%
print(np.mean(tpoint_model - current_model))
# Out:
# 69.323580734454
